# %% [markdown]
# ### Seaborn library itself having datasets

# %%
# listing all datasets from the seaborn library
import seaborn as sns
sns.get_dataset_names()

# %% [markdown]
# ### Loading Data set from the seaborn library

# %%
df = sns.load_dataset('tips')
df.head()

# %%
import pandas as pd
tips=pd.read_csv('tips.csv')
tips.head()

# %% [markdown]
# ## Graphs
#
#     -> Uni-Variant
#
#         -> Single column
#
#     -> Bi-Variant
#
#         -> two columns
#
#     -> Multi-Variant
#
#         -> more than 2 columns

# %% [markdown]
# ## Function interface
#
# ### Relational plots
#
# #### relplot
#
# Figure-level interface for drawing relational plots onto a FacetGrid.
#
# #### scatterplot
#
# Draw a scatter plot with possibility of several semantic groupings.
#
# #### lineplot
#
# Draw a line plot with possibility of several semantic groupings.
#
# ### Distribution plots
#
# #### displot
#
# Figure-level interface for drawing distribution plots onto a FacetGrid.
#
# #### histplot
#
# Plot univariate or bivariate histograms to show distributions of datasets.
#
# #### kdeplot
#
# Plot univariate or bivariate distributions using kernel density estimation.
#
# #### ecdfplot
#
# Plot empirical cumulative distribution functions.
#
# #### rugplot
#
# Plot marginal distributions by drawing ticks along the x and y axes.
#
# #### distplot
#
# DEPRECATED
#
# ### Categorical plots
#
# #### catplot
#
# Figure-level interface for drawing categorical plots onto a FacetGrid.
#
# #### stripplot
#
# Draw a categorical scatterplot using jitter to reduce overplotting.
#
# #### swarmplot
#
# Draw a categorical scatterplot with points adjusted to be non-overlapping.
#
# #### boxplot
#
# Draw a box plot to show distributions with respect to categories.
#
# #### violinplot
#
# Draw a combination of boxplot and kernel density estimate.
#
# #### boxenplot
#
# Draw an enhanced box plot for larger datasets.
#
# #### pointplot
#
# Show point estimates and errors using dot marks.
#
# #### barplot
#
# Show point estimates and errors as rectangular bars.
#
# #### countplot
#
# Show the counts of observations in each categorical bin using bars.
#
# ### Regression plots
#
# #### lmplot
#
# Plot data and regression model fits across a FacetGrid.
#
# #### regplot
#
# Plot data and a linear regression model fit.
#
# #### residplot
#
# Plot the residuals of a linear regression.
#
# ### Matrix plots
#
# #### heatmap
#
# Plot rectangular data as a color-encoded matrix.
#
# #### clustermap
#
# Plot a matrix dataset as a hierarchically-clustered heatmap.
#
# ### Multi-plot grids
#
# ### Facet grids
#
# #### FacetGrid
#
# Multi-plot grid for plotting conditional relationships.
#
# ### Pair grids
#
# #### pairplot
#
# Plot pairwise relationships in a dataset.
#
# #### PairGrid
#
# Subplot grid for plotting pairwise relationships in a dataset.
#
# ### Joint grids
#
# #### jointplot
#
# Draw a plot of two variables with bivariate and univariate graphs.
#
# #### JointGrid
#
# Grid for drawing a bivariate plot with marginal univariate plots.

# %% [markdown]
# ### rel plot

# %%
tips.columns

# %%
tips.head()

# %%
tips.dtypes

# %% [markdown]
# ## Data information of the each and every column
#
# ### Column Name-1: total_bill
#
#    #### Stats Data information
#
#     => Numerical with Continuous Values
#
#    #### Programming Data Type information
#
#     => float
#
#    #### Example presented in data Frame
#
#     => 16.99
#
#
#
# ### tip
#
#     => Numerical with Continuous Values => 3.31 => float
#
# ### sex
#
#     => Characters with Categorical Values => Male => object
#
# ### smoker
#
#     => Characters with Categorical Values => Yes => object
#
# ### day
#
#     => Characters with Categorical Values => Sun => object
#
# ### time
#
#     => Characters with Categorical Values => Dinner => object
#
# ### size
#
#     => numbers with categorical Values => 4 => int

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#df=sns.load_dataset('tips')
df=pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe(include='object')
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
sns.relplot(data=df, x ='total_bill',y='tip')

# %%
sns.relplot(data=df, x="total_bill", y="tip")
plt.show()

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="day")
plt.show()

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="day", col="time")
plt.show()

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="day", col="time", row="sex")
plt.show()

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="time", col="day")
plt.show()

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="time", col="day", col_wrap=2)
plt.show()

# %%
sns.relplot(
    data=df, x="total_bill", y="tip", col="time",
    hue="day", size="size", style="sex",
    palette=['#fb1414', '#C903CE', '#0088CC', '#04C809'], sizes=(10, 100)
)
plt.show()

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="time", col="size",col_wrap=3)
plt.show()

# %%
tips = sns.load_dataset("tips")

# %% [markdown]
# ### Scatter plot

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
plt.show()

# %% [markdown]
# ### lineplot

# %%
flights = sns.load_dataset("flights")
may_flights = flights.query("month == 'May'")
sns.lineplot(data=may_flights, x="year", y="passengers")
plt.show()

# %%
flights_wide = flights.pivot("year", "month", "passengers")
sns.lineplot(data=flights_wide)

# %% [markdown]
# ### displot

# %%
penguins = sns.load_dataset("penguins")
sns.displot(data=penguins, x="flipper_length_mm")
plt.show()

# %%
sns.displot(data=penguins, x="flipper_length_mm", kind="kde")
plt.show()

# %%
sns.displot(data=penguins, x="flipper_length_mm", kind="ecdf")
plt.show()

# %%
sns.displot(data=penguins, x="flipper_length_mm", kde=True)
plt.show()

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
plt.show()

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", col="sex", kind="kde")
plt.show()

# %% [markdown]
# ### histplot

# %%
sns.histplot(data=penguins, x="flipper_length_mm")
plt.show()

# %%
sns.histplot(data=penguins, y="flipper_length_mm")
plt.show()

# %%
sns.histplot(data=penguins, x="flipper_length_mm", binwidth=3)
plt.show()

# %%
sns.histplot(data=penguins, x="flipper_length_mm", bins=30)
plt.show()

# %%
sns.histplot(data=penguins, x="flipper_length_mm", kde=True)
plt.show()

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species")
plt.show()

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species", element="step")
plt.show()

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species", element="poly")
plt.show()

# %%
sns.histplot(data=tips, x="day", hue="sex", multiple="dodge", shrink=.8)
plt.show()

# %%
planets = sns.load_dataset("planets")
sns.histplot(data=planets, x="distance", log_scale=True, fill=False)
plt.show()

# %%
sns.histplot(data=planets, x="distance", log_scale=True, element="step", fill=False)
plt.show()

# %% [markdown]
# ### kdeplot

# %%
tips = sns.load_dataset("tips")
sns.kdeplot(data=tips, x="total_bill")
plt.show()

# %%
iris = sns.load_dataset("iris")
sns.kdeplot(data=iris)
plt.show()

# %%
sns.kdeplot(data=tips, x="total_bill", hue="time")
plt.show()

# %%
sns.kdeplot(data=tips, x="total_bill", hue="time", multiple="fill")
plt.show()

# %% [markdown]
# ### ecdfplot

# %%
penguins = sns.load_dataset("penguins")
sns.ecdfplot(data=penguins, x="flipper_length_mm")
plt.show()

# %% [markdown]
# ### rugplot

# %%
import seaborn as sns; sns.set_theme()
tips = sns.load_dataset("tips")
sns.kdeplot(data=tips, x="total_bill")
sns.rugplot(data=tips, x="total_bill")
plt.show()

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
sns.rugplot(data=tips, x="total_bill", y="tip")
plt.show()

# %% [markdown]
# ### catplot

# %%
df = sns.load_dataset("titanic")
sns.catplot(data=df, x="age", y="class")
plt.show()

# %% [markdown]
# ### stripplot

# %%
sns.stripplot(data=tips, x="total_bill")
plt.show()

# %%
sns.stripplot(data=tips, x="total_bill", y="day")
plt.show()

# %%
sns.stripplot(data=tips, x="total_bill", y="day", hue="day")
plt.show()

# %%
sns.stripplot(data=tips, x="total_bill", y="day", hue="sex")
plt.show()

# %%
sns.stripplot(data=tips, x="total_bill", y="day", hue="sex", dodge=True)
plt.show()

# %% [markdown]
# ### swarmplot

# %%
sns.swarmplot(data=tips, x="total_bill")
plt.show()

# %% [markdown]
# ### boxplot

# %%
df = sns.load_dataset("titanic")
sns.boxplot(data = df,x="age")
plt.show()

# %%
sns.boxplot(data=df, x="age", y="class")
plt.show()

# %%
sns.boxplot(data=df, x="age", y="class", hue="alive")
plt.show()

# %%
sns.boxplot(data=df, x="fare", y="alive", order=["yes", "no"])
plt.show()

# %%
sns.boxplot(data=df[["age", "fare"]], orient="h")
plt.show()

# %%
sns.boxplot(data=df, x="fare", y="deck", hue="deck", dodge=False)
plt.show()

# %%
sns.boxplot(
    data=df, x="age", y="class",
    notch=True, showcaps=False,
    flierprops={"marker": "x"},
    boxprops={"facecolor": (.4, .6, .8, .5)},
    medianprops={"color": "coral"},
)
plt.show()

# %% [markdown]
# ### violinplot

# %%
df = sns.load_dataset("titanic")
sns.violinplot(x=df["age"])
plt.show()

# %% [markdown]
# ###  boxenplot

# %%
df = sns.load_dataset("titanic")
sns.boxenplot(x=df["age"])
plt.show()

# %% [markdown]
# ### pointplot

# %%
df = sns.load_dataset("penguins")
sns.pointplot(data=df, x="island", y="body_mass_g")
plt.show()

# %% [markdown]
# ### barplot

# %%
df = sns.load_dataset("penguins")
sns.barplot(data=df, x="island", y="body_mass_g")
plt.show()

# %% [markdown]
# ### countplot

# %%
df = sns.load_dataset("titanic")
sns.countplot(x=df["class"])
plt.show()

# %%
sns.countplot(data=df, y="deck", hue="alive")
plt.show()

# %% [markdown]
# ### lmplot

# %%
tips = sns.load_dataset("tips")
g = sns.lmplot(x="total_bill", y="tip", data=tips)
plt.show()

# %% [markdown]
# ### regplot

# %%
import seaborn as sns; sns.set_theme(color_codes=True)
tips = sns.load_dataset("tips")
ax = sns.regplot(x="total_bill", y="tip", data=tips)
plt.show()

# %% [markdown]
# ### residplot

# %%
ax = sns.residplot(x="total_bill", y="tip", data=tips)
plt.show()

# %% [markdown]
# ### heatmap

# %%
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
sns.heatmap(flights, annot=True, fmt="d")
plt.show()

# %%
tips = sns.load_dataset('tips')
tips.head()

# %% [markdown]
# ### FacetGrid

# %%
g = sns.FacetGrid(tips, col="time",  row="sex")
g.map(sns.scatterplot, "total_bill", "tip")
plt.show()

# %% [markdown]
# ### pairplot

# %%
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips, hue="sex")
plt.show()

# %% [markdown]
# ### PairGrid

# %%
g = sns.PairGrid(tips)
g.map(sns.scatterplot)
plt.show()

# %% [markdown]
# ### jointplot

# %%
penguins = sns.load_dataset("penguins")
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")
plt.show()

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")
plt.show()

# %% [markdown]
# ### JointGrid

# %%
g = sns.JointGrid(data=penguins, x="bill_length_mm", y="bill_depth_mm")
g.plot(sns.scatterplot, sns.kdeplot)
plt.show()
